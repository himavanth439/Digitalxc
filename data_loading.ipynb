# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
data = r"C:\Users\excel\OneDrive\Desktop\Sample Data file for Analysis_Jan'25.xlsx"
df = pd.read_excel(data)
df
# Out:
#                Ticket ID                 Category  \
# 0      Event Management          Business Service
# 1      Event Management          Business Service
# 2      Event Management   Hardware-Infrastructure
# 3      Event Management   Hardware-Infrastructure
# 4      Event Management   Hardware-Infrastructure
# ...                  ...                      ...
# 4994  ITSM-PO Functional                 Software
# 4995  ITSM-PO Functional                 Software
# 4996  ITSM-PO Functional                 Software
# 4997  ITSM-PO Functional                 Software
# 4998  ITSM-PO Functional                 Software
#
#                                        sub-category      priority  \
# 0     GRP56.34 PRXX (DigitalC Workplace management)  3 - Moderate
# 1     GRP56.34 PRXX (DigitalC Workplace management)  3 - Moderate
# 2            NxGen Tech. Business SErvices - Backup  3 - Moderate
# 3            NxGen Tech. Business SErvices - Backup  3 - Moderate
# ...

# %%
pip install psycopg2
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 14.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 19.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show psycopg2
# Out:
# Name: psycopg2
# Version: 2.9.10
# Summary: psycopg2 - Python-PostgreSQL Database Adapter
# Home-page: https://psycopg.org/
# Author: Federico Di Gregorio
# Author-email: fog@initd.org
# License: LGPL with exceptions
# Location: C:\Users\excel\anaconda3\Lib\site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql+psycopg2://postgres:hima12345@localhost:5432/project")
connection = engine.connect()
print("Connection successful!")
connection.close()
# Out:
# Connection successful!

# %%
df.to_sql("sample", engine, if_exists="replace", index=False)
print("Data successfully loaded!")
# Out:
# Data successfully loaded!

# %%
pip install dbt-core dbt-postgres
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/944.6 kB ? eta -:--:--
#    ---------------------------------------- 944.6/944.6 kB 8.7 MB/s eta 0:00:00
# ...
#   Created wheel for daff: filename=daff-1.3.46-py3-none-any.whl size=146126 sha256=00922a4689b234a0754ce676d26f1831a828772208a93e292fd650b7bad45dba
#   Stored in directory: c:\users\excel\appdata\local\pip\cache\wheels\88\ad\49\13ff24b45a6c4e12e5ae48071f7a63d6b78a475b179e01b54e
# Successfully built daff
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# ...

# %%
pip install dbt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
